# %%
# !g++ 2a.cpp - o 2a
# !echo 15 | 2a.exe
# Out:
# g++: error: -E or -x required when input is from standard input
# Test case  : 30

# %%
# !g++ 2a.cpp - o 2a
# !echo 5 | 2a.exe
# Out:
# g++: error: -E or -x required when input is from standard input
# Test case  : -5

# %%
# !g++ 2a.cpp - o 2a
# !echo -10 | 2a.exe
# Out:
# g++: error: -E or -x required when input is from standard input
# Test case  : 10
